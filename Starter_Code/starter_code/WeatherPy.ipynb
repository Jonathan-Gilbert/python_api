# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | lepsy
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | black forest
# Processing Record 6 of Set 1 | sisimiut
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mont-dore
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | port mathurin
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | vorgashor
# Processing Record 14 of Set 1 | wailua homesteads
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | pimentel
# Processing Record 18 of Set 1 | edinburgh of the seven seas
# Processing Record 19 of Set 1 | la passe
# Processing Record 20 of Set 1 | savelugu
# Processing Record 21 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | la'ie
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 1 | timbuktu
# Processing Record 29 of Set 1 | ust-nera
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | bilibino
# Processing Record 32 of Set 1 | coracora
# Processing Record 33 of Set 1 | blackmans bay
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | korla
# Processing Record 36 of Set 1 | santa luzia
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | villa ojo de agua
# Processing Record 40 of Set 1 | revda
# Processing Record 41 of Set 1 | cestos city
# Processing Record 42 of Set 1 | mugia
# Processing Record 43 of Set 1 | qeshm
# Processing Record 44 of Set 1 | colonia
# Processing Record 45 of Set 1 | lincheng
# Processing Record 46 of Set 1 | little cayman
# City not found. Skipping...
# Processing Record 47 of Set 1 | olonkinbyen
# Processing Record 48 of Set 1 | ijuw
# City not found. Skipping...
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | minas de marcona
# Processing Record 0 of Set 2 | hawaiian paradise park
# Processing Record 1 of Set 2 | anadyr
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | xai-xai
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 2 | maintirano
# Processing Record 7 of Set 2 | north bay
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | invercargill
# Processing Record 10 of Set 2 | nar'yan-mar
# Processing Record 11 of Set 2 | grytviken
# Processing Record 12 of Set 2 | tual
# Processing Record 13 of Set 2 | margaret river
# Processing Record 14 of Set 2 | uturoa
# Processing Record 15 of Set 2 | tura
# Processing Record 16 of Set 2 | beaufort west
# Processing Record 17 of Set 2 | saipan
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | haiku-pauwela
# Processing Record 21 of Set 2 | savave village
# City not found. Skipping...
# Processing Record 22 of Set 2 | valdoie
# Processing Record 23 of Set 2 | timimoun
# Processing Record 24 of Set 2 | west island
# Processing Record 25 of Set 2 | aasiaat
# Processing Record 26 of Set 2 | vilyuchinsk
# Processing Record 27 of Set 2 | fairbanks
# Processing Record 28 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 2 | sos'va
# Processing Record 30 of Set 2 | porto seguro
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | umatac village
# City not found. Skipping...
# Processing Record 33 of Set 2 | khanty-mansiysk
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | conception bay south
# Processing Record 36 of Set 2 | badger
# Processing Record 37 of Set 2 | holualoa
# Processing Record 38 of Set 2 | sol'-iletsk
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | papatowai
# Processing Record 41 of Set 2 | robertsport
# Processing Record 42 of Set 2 | nampa
# Processing Record 43 of Set 2 | yuzhno-kurilsk
# Processing Record 44 of Set 2 | bielsk podlaski
# Processing Record 45 of Set 2 | jaru
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | happy valley-goose bay
# Processing Record 48 of Set 2 | derventa
# Processing Record 49 of Set 2 | hemsby
# Processing Record 0 of Set 3 | guerrero negro
# Processing Record 1 of Set 3 | puerto baquerizo moreno
# Processing Record 2 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 3 of Set 3 | shakiso
# Processing Record 4 of Set 3 | mejit
# Processing Record 5 of Set 3 | moranbah
# Processing Record 6 of Set 3 | rancho palos verdes
# Processing Record 7 of Set 3 | bandarbeyla
# Processing Record 8 of Set 3 | shippensburg
# Processing Record 9 of Set 3 | peace river
# Processing Record 10 of Set 3 | pirot
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | taltal
# Processing Record 13 of Set 3 | orsa
# Processing Record 14 of Set 3 | berrahal
# Processing Record 15 of Set 3 | murudeshwara
# Processing Record 16 of Set 3 | taroa
# Processing Record 17 of Set 3 | salinas
# Processing Record 18 of Set 3 | kuala belait
# Processing Record 19 of Set 3 | iskateley
# Processing Record 20 of Set 3 | shiyan
# Processing Record 21 of Set 3 | lihue
# Processing Record 22 of Set 3 | umm kaddadah
# Processing Record 23 of Set 3 | laurel
# Processing Record 24 of Set 3 | utrik
# Processing Record 25 of Set 3 | afaahiti
# Processing Record 26 of Set 3 | chonchi
# Processing Record 27 of Set 3 | freeport
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | tomatlan
# Processing Record 30 of Set 3 | douglas
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | mablethorpe
# City not found. Skipping...
# Processing Record 33 of Set 3 | colonia menno
# Processing Record 34 of Set 3 | cihanbeyli
# Processing Record 35 of Set 3 | narasannapeta
# Processing Record 36 of Set 3 | la sarre
# Processing Record 37 of Set 3 | christchurch
# Processing Record 38 of Set 3 | gaspe
# Processing Record 39 of Set 3 | qaqortoq
# Processing Record 40 of Set 3 | peterhead
# Processing Record 41 of Set 3 | dosso
# Processing Record 42 of Set 3 | ambon
# Processing Record 43 of Set 3 | manokwari
# Processing Record 44 of Set 3 | chimbarongo
# Processing Record 45 of Set 3 | karratha
# Processing Record 46 of Set 3 | prince rupert
# Processing Record 47 of Set 3 | camana
# Processing Record 48 of Set 3 | rongelap
# Processing Record 49 of Set 3 | atafu village
# Processing Record 0 of Set 4 | codrington
# Processing Record 1 of Set 4 | luorong
# Processing Record 2 of Set 4 | floro
# Processing Record 3 of Set 4 | la punta
# Processing Record 4 of Set 4 | piacabucu
# Processing Record 5 of Set 4 | aban
# Processing Record 6 of Set 4 | island harbour
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | klyuchi
# Processing Record 9 of Set 4 | ta`u
# Processing Record 10 of Set 4 | usogorsk
# Processing Record 11 of Set 4 | malango
# Processing Record 12 of Set 4 | las lomitas
# Processing Record 13 of Set 4 | nova sintra
# Processing Record 14 of Set 4 | gadani
# Processing Record 15 of Set 4 | richmond
# Processing Record 16 of Set 4 | pitimbu
# Processing Record 17 of Set 4 | kununurra
# Processing Record 18 of Set 4 | aqaba
# Processing Record 19 of Set 4 | bacalar
# Processing Record 20 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 21 of Set 4 | constantia
# Processing Record 22 of Set 4 | queenstown
# Processing Record 23 of Set 4 | sabang
# Processing Record 24 of Set 4 | newport
# Processing Record 25 of Set 4 | fort beaufort
# Processing Record 26 of Set 4 | port lincoln
# Processing Record 27 of Set 4 | badiyah
# Processing Record 28 of Set 4 | argo
# Processing Record 29 of Set 4 | quellon
# Processing Record 30 of Set 4 | port hueneme
# Processing Record 31 of Set 4 | port shepstone
# Processing Record 32 of Set 4 | mont-de-marsan
# Processing Record 33 of Set 4 | stanley
# Processing Record 34 of Set 4 | gorontalo
# Processing Record 35 of Set 4 | puerto ayora
# Processing Record 36 of Set 4 | lazaro cardenas
# Processing Record 37 of Set 4 | vila franca do campo
# Processing Record 38 of Set 4 | muisne
# Processing Record 39 of Set 4 | ebon
# Processing Record 40 of Set 4 | tucupita
# Processing Record 41 of Set 4 | leh
# Processing Record 42 of Set 4 | saint joseph
# Processing Record 43 of Set 4 | choibalsan
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | cill airne
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | portel
# Processing Record 48 of Set 4 | mana
# Processing Record 49 of Set 4 | belmonte
# Processing Record 0 of Set 5 | setti fatma
# City not found. Skipping...
# Processing Record 1 of Set 5 | renigunta
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | marvdasht
# City not found. Skipping...
# Processing Record 4 of Set 5 | udachny
# Processing Record 5 of Set 5 | champerico
# Processing Record 6 of Set 5 | guaruja
# Processing Record 7 of Set 5 | padang
# Processing Record 8 of Set 5 | coaldale
# Processing Record 9 of Set 5 | wegrow
# Processing Record 10 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 11 of Set 5 | imeni morozova
# Processing Record 12 of Set 5 | nova olinda do norte
# Processing Record 13 of Set 5 | remire-montjoly
# Processing Record 14 of Set 5 | mukalla
# Processing Record 15 of Set 5 | liwale
# Processing Record 16 of Set 5 | taoudenni
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | tolanaro
# Processing Record 19 of Set 5 | antsohihy
# Processing Record 20 of Set 5 | rikaze
# Processing Record 21 of Set 5 | al 'amarah
# Processing Record 22 of Set 5 | forster
# Processing Record 23 of Set 5 | mizdah
# Processing Record 24 of Set 5 | beyneu
# Processing Record 25 of Set 5 | enewetak
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | thunder bay
# Processing Record 28 of Set 5 | port hedland
# Processing Record 29 of Set 5 | greenville
# Processing Record 30 of Set 5 | pleiku
# Processing Record 31 of Set 5 | key west
# Processing Record 32 of Set 5 | ain oussera
# Processing Record 33 of Set 5 | novyy urengoy
# Processing Record 34 of Set 5 | guilin
# Processing Record 35 of Set 5 | san pedro pochutla
# Processing Record 36 of Set 5 | mahina
# Processing Record 37 of Set 5 | kaihua
# Processing Record 38 of Set 5 | angaur state
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | fisterra
# Processing Record 41 of Set 5 | orichi
# Processing Record 42 of Set 5 | chengde
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | dudinka
# Processing Record 45 of Set 5 | pyhajarvi
# Processing Record 46 of Set 5 | flin flon
# Processing Record 47 of Set 5 | montanha
# Processing Record 48 of Set 5 | kapuskasing
# Processing Record 49 of Set 5 | terneuzen
# Processing Record 0 of Set 6 | baganga
# Processing Record 1 of Set 6 | alotau
# Processing Record 2 of Set 6 | ta'izz
# Processing Record 3 of Set 6 | chibougamau
# Processing Record 4 of Set 6 | shelburne
# Processing Record 5 of Set 6 | coronel dorrego
# Processing Record 6 of Set 6 | kabalo
# Processing Record 7 of Set 6 | port blair
# Processing Record 8 of Set 6 | fitzgerald
# Processing Record 9 of Set 6 | nemuro
# Processing Record 10 of Set 6 | kaga bandoro
# Processing Record 11 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 12 of Set 6 | midvagur
# Processing Record 13 of Set 6 | akobo
# Processing Record 14 of Set 6 | parnu
# Processing Record 15 of Set 6 | perry
# Processing Record 16 of Set 6 | fale old settlement
# Processing Record 17 of Set 6 | loukhi
# Processing Record 18 of Set 6 | calatayud
# Processing Record 19 of Set 6 | sinop
# Processing Record 20 of Set 6 | st. john's
# Processing Record 21 of Set 6 | kingston
# Processing Record 22 of Set 6 | chicxulub puerto
# City not found. Skipping...
# Processing Record 23 of Set 6 | vadso
# Processing Record 24 of Set 6 | piton saint-leu
# Processing Record 25 of Set 6 | cabinda
# Processing Record 26 of Set 6 | weno
# Processing Record 27 of Set 6 | sale
# Processing Record 28 of Set 6 | pontes e lacerda
# Processing Record 29 of Set 6 | port augusta
# Processing Record 30 of Set 6 | chabahar
# Processing Record 31 of Set 6 | sao vicente
# Processing Record 32 of Set 6 | ola
# Processing Record 33 of Set 6 | al fqih ben calah
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | nadym
# Processing Record 36 of Set 6 | novyy urgal
# Processing Record 37 of Set 6 | xining
# Processing Record 38 of Set 6 | atherton
# Processing Record 39 of Set 6 | khovd
# Processing Record 40 of Set 6 | prainha
# Processing Record 41 of Set 6 | el bauga
# Processing Record 42 of Set 6 | souillac
# Processing Record 43 of Set 6 | yelizovo
# Processing Record 44 of Set 6 | zaozersk
# Processing Record 45 of Set 6 | khromtau
# Processing Record 46 of Set 6 | hami
# Processing Record 47 of Set 6 | mount carmel
# Processing Record 48 of Set 6 | plettenberg bay
# Processing Record 49 of Set 6 | bandundu
# Processing Record 0 of Set 7 | belokurikha
# Processing Record 1 of Set 7 | miquelon
# Processing Record 2 of Set 7 | el hadjira
# Processing Record 3 of Set 7 | ankeny
# Processing Record 4 of Set 7 | sao joao da ponte
# Processing Record 5 of Set 7 | kashgar
# Processing Record 6 of Set 7 | fortuna
# Processing Record 7 of Set 7 | pizhou
# Processing Record 8 of Set 7 | san-pedro
# Processing Record 9 of Set 7 | rexburg
# Processing Record 10 of Set 7 | fish town
# Processing Record 11 of Set 7 | howard springs
# Processing Record 12 of Set 7 | acapulco de juarez
# Processing Record 13 of Set 7 | bridgetown
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | thompson
# Processing Record 16 of Set 7 | kyzylorda
# Processing Record 17 of Set 7 | zhezqazghan
# Processing Record 18 of Set 7 | zouerate
# Processing Record 19 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 20 of Set 7 | aldinga beach
# Processing Record 21 of Set 7 | usinsk
# Processing Record 22 of Set 7 | yeppoon
# Processing Record 23 of Set 7 | saurimo
# Processing Record 24 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 25 of Set 7 | le port
# Processing Record 26 of Set 7 | ndikinimeki
# Processing Record 27 of Set 7 | madaoua
# Processing Record 28 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 29 of Set 7 | carnarvon
# Processing Record 30 of Set 7 | al majaridah
# Processing Record 31 of Set 7 | luanda
# Processing Record 32 of Set 7 | primero de mayo
# Processing Record 33 of Set 7 | saldanha
# Processing Record 34 of Set 7 | chegutu
# Processing Record 35 of Set 7 | verdun
# Processing Record 36 of Set 7 | aleg
# Processing Record 37 of Set 7 | puerto lleras
# Processing Record 38 of Set 7 | balsthal
# Processing Record 39 of Set 7 | junin
# Processing Record 40 of Set 7 | torres
# Processing Record 41 of Set 7 | northam
# Processing Record 42 of Set 7 | ghanzi
# Processing Record 43 of Set 7 | trapani
# Processing Record 44 of Set 7 | port saint john's
# Processing Record 45 of Set 7 | lomza
# Processing Record 46 of Set 7 | vernon
# Processing Record 47 of Set 7 | petauke
# Processing Record 48 of Set 7 | shenjiamen
# Processing Record 49 of Set 7 | colatina
# Processing Record 0 of Set 8 | qianzhou
# Processing Record 1 of Set 8 | tataouine
# Processing Record 2 of Set 8 | fort bragg
# Processing Record 3 of Set 8 | nago
# Processing Record 4 of Set 8 | chrudim
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | olbia
# Processing Record 7 of Set 8 | sur
# Processing Record 8 of Set 8 | puerto la cruz
# Processing Record 9 of Set 8 | demopolis
# Processing Record 10 of Set 8 | warrenpoint
# Processing Record 11 of Set 8 | susuman
# Processing Record 12 of Set 8 | nyurba
# Processing Record 13 of Set 8 | seen (kreis 3)
# Processing Record 14 of Set 8 | bua yai
# Processing Record 15 of Set 8 | bowie
# Processing Record 16 of Set 8 | whitehorse
# Processing Record 17 of Set 8 | findlay
# Processing Record 18 of Set 8 | akrehamn
# Processing Record 19 of Set 8 | salekhard
# Processing Record 20 of Set 8 | sanctuary point
# Processing Record 21 of Set 8 | sola
# Processing Record 22 of Set 8 | ubari
# Processing Record 23 of Set 8 | katsuren-haebaru
# Processing Record 24 of Set 8 | keflavik
# Processing Record 25 of Set 8 | withernsea
# Processing Record 26 of Set 8 | nuku'alofa
# Processing Record 27 of Set 8 | bardai
# Processing Record 28 of Set 8 | sittwe
# Processing Record 29 of Set 8 | prades
# Processing Record 30 of Set 8 | port-vila
# Processing Record 31 of Set 8 | hammerfest
# Processing Record 32 of Set 8 | hilo
# Processing Record 33 of Set 8 | fort mcmurray
# Processing Record 34 of Set 8 | abepura
# Processing Record 35 of Set 8 | harper
# Processing Record 36 of Set 8 | sweetwater
# Processing Record 37 of Set 8 | tervel
# Processing Record 38 of Set 8 | dongkan
# Processing Record 39 of Set 8 | bom jesus
# Processing Record 40 of Set 8 | tafuna
# Processing Record 41 of Set 8 | altamira
# Processing Record 42 of Set 8 | sirjan
# Processing Record 43 of Set 8 | youhao
# Processing Record 44 of Set 8 | uthal
# Processing Record 45 of Set 8 | siwa oasis
# Processing Record 46 of Set 8 | buala
# Processing Record 47 of Set 8 | itoman
# Processing Record 48 of Set 8 | isafjordur
# Processing Record 49 of Set 8 | ocean shores
# Processing Record 0 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 1 of Set 9 | gisborne
# Processing Record 2 of Set 9 | tianpeng
# Processing Record 3 of Set 9 | palikir - national government center
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 6 of Set 9 | berdigestyakh
# Processing Record 7 of Set 9 | winnemucca
# Processing Record 8 of Set 9 | paradip garh
# Processing Record 9 of Set 9 | walvis bay
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | saint croix
# Processing Record 12 of Set 9 | joshimath
# Processing Record 13 of Set 9 | pachperwa
# Processing Record 14 of Set 9 | elva
# Processing Record 15 of Set 9 | zheshart
# Processing Record 16 of Set 9 | enriquillo
# Processing Record 17 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 18 of Set 9 | san javier
# Processing Record 19 of Set 9 | la paz
# Processing Record 20 of Set 9 | saint-amand-montrond
# Processing Record 21 of Set 9 | bodo
# Processing Record 22 of Set 9 | kapa'a
# Processing Record 23 of Set 9 | rundu
# Processing Record 24 of Set 9 | barra da estiva
# Processing Record 25 of Set 9 | selkirk
# Processing Record 26 of Set 9 | cochin
# Processing Record 27 of Set 9 | dzhangala
# Processing Record 28 of Set 9 | yeed
# Processing Record 29 of Set 9 | mount isa
# Processing Record 30 of Set 9 | goba
# Processing Record 31 of Set 9 | bathsheba
# Processing Record 32 of Set 9 | laguna
# Processing Record 33 of Set 9 | kailua-kona
# Processing Record 34 of Set 9 | sao gabriel da cachoeira
# Processing Record 35 of Set 9 | ngetkib
# Processing Record 36 of Set 9 | ngaoundere
# Processing Record 37 of Set 9 | strangnas
# Processing Record 38 of Set 9 | mulki
# Processing Record 39 of Set 9 | polyarnyy
# Processing Record 40 of Set 9 | coquimbo
# Processing Record 41 of Set 9 | najran
# Processing Record 42 of Set 9 | dongola
# Processing Record 43 of Set 9 | al jumum
# Processing Record 44 of Set 9 | luang prabang
# Processing Record 45 of Set 9 | tangalle
# Processing Record 46 of Set 9 | opuwo
# Processing Record 47 of Set 9 | lawas
# Processing Record 48 of Set 9 | aykhal
# Processing Record 49 of Set 9 | san patricio
# Processing Record 0 of Set 10 | kerikeri
# Processing Record 1 of Set 10 | el bolson
# Processing Record 2 of Set 10 | hasaki
# Processing Record 3 of Set 10 | manismata
# Processing Record 4 of Set 10 | gonen
# Processing Record 5 of Set 10 | midland
# Processing Record 6 of Set 10 | shubarshi
# Processing Record 7 of Set 10 | asan-maina village
# Processing Record 8 of Set 10 | igarka
# Processing Record 9 of Set 10 | severo-yeniseyskiy
# Processing Record 10 of Set 10 | posto fiscal rolim de moura
# Processing Record 11 of Set 10 | brisas de zicatela
# Processing Record 12 of Set 10 | dhidhdhoo
# Processing Record 13 of Set 10 | karasburg
# Processing Record 14 of Set 10 | bodaybo
# Processing Record 15 of Set 10 | nikol'sk
# Processing Record 16 of Set 10 | duobao
# Processing Record 17 of Set 10 | hazebrouck
# Processing Record 18 of Set 10 | farasan
# Processing Record 19 of Set 10 | jatiroto
# Processing Record 20 of Set 10 | jabor
# Processing Record 21 of Set 10 | missoula
# Processing Record 22 of Set 10 | gadzhiyevo
# Processing Record 23 of Set 10 | kotka
# Processing Record 24 of Set 10 | sao sebastiao do passe
# Processing Record 25 of Set 10 | lerwick
# Processing Record 26 of Set 10 | thaton
# Processing Record 27 of Set 10 | chantada
# Processing Record 28 of Set 10 | nagqu
# Processing Record 29 of Set 10 | topolobampo
# Processing Record 30 of Set 10 | pangody
# Processing Record 31 of Set 10 | sidon
# Processing Record 32 of Set 10 | sassandra
# Processing Record 33 of Set 10 | mount pearl
# Processing Record 34 of Set 10 | mujiayingzi
# Processing Record 35 of Set 10 | burgos
# Processing Record 36 of Set 10 | mareeba
# Processing Record 37 of Set 10 | santa cruz verapaz
# Processing Record 38 of Set 10 | punta del este
# Processing Record 39 of Set 10 | trairi
# Processing Record 40 of Set 10 | cam ranh
# Processing Record 41 of Set 10 | kinkala
# Processing Record 42 of Set 10 | bei'an
# Processing Record 43 of Set 10 | banda aceh
# Processing Record 44 of Set 10 | cururupu
# Processing Record 45 of Set 10 | arkhangel'sk
# Processing Record 46 of Set 10 | al hufuf
# Processing Record 47 of Set 10 | slyudyanka
# Processing Record 48 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 49 of Set 10 | castillos
# Processing Record 0 of Set 11 | lusambo
# Processing Record 1 of Set 11 | mawu
# Processing Record 2 of Set 11 | gedo
# Processing Record 3 of Set 11 | tubarjal
# Processing Record 4 of Set 11 | salinopolis
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | mata-utu
# Processing Record 7 of Set 11 | lafia
# Processing Record 8 of Set 11 | tejen
# Processing Record 9 of Set 11 | quba
# Processing Record 10 of Set 11 | calca
# Processing Record 11 of Set 11 | onega
# Processing Record 12 of Set 11 | nawada
# Processing Record 13 of Set 11 | antonio enes
# Processing Record 14 of Set 11 | parauapebas
# Processing Record 15 of Set 11 | soio
# Processing Record 16 of Set 11 | goure
# Processing Record 17 of Set 11 | keyser
# Processing Record 18 of Set 11 | rio tuba
# Processing Record 19 of Set 11 | san mariano
# Processing Record 20 of Set 11 | olovyannaya
# Processing Record 21 of Set 11 | kiama
# Processing Record 22 of Set 11 | ayaguz
# City not found. Skipping...
# Processing Record 23 of Set 11 | hondo
# Processing Record 24 of Set 11 | vylkove
# Processing Record 25 of Set 11 | howrah
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | lamu
# Processing Record 28 of Set 11 | lompoc
# Processing Record 29 of Set 11 | mount darwin
# Processing Record 30 of Set 11 | ajaccio
# Processing Record 31 of Set 11 | cabrobo
# Processing Record 32 of Set 11 | piraeus
# Processing Record 33 of Set 11 | freistadt
# Processing Record 34 of Set 11 | coahuayana de hidalgo
# Processing Record 35 of Set 11 | mboursou lere
# Processing Record 36 of Set 11 | bonthe
# Processing Record 37 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 38 of Set 11 | goiania
# Processing Record 39 of Set 11 | talnakh
# Processing Record 40 of Set 11 | miranda do douro
# Processing Record 41 of Set 11 | kirakira
# Processing Record 42 of Set 11 | cole harbour
# Processing Record 43 of Set 11 | tres lagoas
# Processing Record 44 of Set 11 | carrizal
# Processing Record 45 of Set 11 | freetown
# Processing Record 46 of Set 11 | dauphin
# Processing Record 47 of Set 11 | kilindoni
# Processing Record 48 of Set 11 | hohhot
# Processing Record 49 of Set 11 | tanjung pandan
# Processing Record 0 of Set 12 | sunzha
# Processing Record 1 of Set 12 | arteche
# Processing Record 2 of Set 12 | miyako
# Processing Record 3 of Set 12 | maragogi
# Processing Record 4 of Set 12 | kenai
# Processing Record 5 of Set 12 | road town
# Processing Record 6 of Set 12 | ust'-ilimsk
# Processing Record 7 of Set 12 | bayanhongor
# Processing Record 8 of Set 12 | selfoss
# Processing Record 9 of Set 12 | kourou
# Processing Record 10 of Set 12 | mandalgovi
# Processing Record 11 of Set 12 | quelimane
# Processing Record 12 of Set 12 | nogliki
# Processing Record 13 of Set 12 | merizo village
# Processing Record 14 of Set 12 | kurchatov
# Processing Record 15 of Set 12 | chernyshevskiy
# Processing Record 16 of Set 12 | padangsidempuan
# Processing Record 17 of Set 12 | yonmu
# Processing Record 18 of Set 12 | shchigry
# Processing Record 19 of Set 12 | gamay
# Processing Record 20 of Set 12 | fort st. john
# Processing Record 21 of Set 12 | sawang daen din
# Processing Record 22 of Set 12 | kushiro
# Processing Record 23 of Set 12 | sarkand
# Processing Record 24 of Set 12 | vorkuta
# Processing Record 25 of Set 12 | wainwright
# Processing Record 26 of Set 12 | payyannur
# Processing Record 27 of Set 12 | nelson
# Processing Record 28 of Set 12 | inari
# Processing Record 29 of Set 12 | wenchang
# Processing Record 30 of Set 12 | naracoorte
# Processing Record 31 of Set 12 | makurazaki
# Processing Record 32 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 12 | boda
# Processing Record 34 of Set 12 | yung shue wan
# Processing Record 35 of Set 12 | arthur's town
# City not found. Skipping...
# Processing Record 36 of Set 12 | raja
# Processing Record 37 of Set 12 | caala
# Processing Record 38 of Set 12 | salalah
# Processing Record 39 of Set 12 | kermanshah
# Processing Record 40 of Set 12 | de aar
# Processing Record 41 of Set 12 | long beach
# Processing Record 42 of Set 12 | nampula
# Processing Record 43 of Set 12 | tobelo
# Processing Record 44 of Set 12 | dampit
# Processing Record 45 of Set 12 | rabo de peixe
# Processing Record 46 of Set 12 | antalaha
# Processing Record 47 of Set 12 | cidreira
# Processing Record 48 of Set 12 | rudnichnyy
# Processing Record 49 of Set 12 | new norfolk
# Processing Record 0 of Set 13 | kavaratti
# Processing Record 1 of Set 13 | jaicos
# Processing Record 2 of Set 13 | dolisie
# Processing Record 3 of Set 13 | pandan
# Processing Record 4 of Set 13 | anabar
# City not found. Skipping...
# Processing Record 5 of Set 13 | severoural'sk
# Processing Record 6 of Set 13 | hancheng
# Processing Record 7 of Set 13 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 13 | toga village
# City not found. Skipping...
# Processing Record 9 of Set 13 | daru
# Processing Record 10 of Set 13 | nykarleby
# Processing Record 11 of Set 13 | hell-ville
# Processing Record 12 of Set 13 | armacao de buzios
# Processing Record 13 of Set 13 | roma
# Processing Record 14 of Set 13 | ulladulla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     adamstown -25.0660 -130.1015     21.29        87         100
# 1     ilulissat  69.2167  -51.1000     -1.99        43          46
# 2         lepsy  46.2350   78.9456     17.30        35         100
# 3        bethel  41.3712  -73.4140      9.05        69           0
# 4  black forest  39.0131 -104.7008     16.55        29           0
#
#    Wind Speed Country        Date
# 0        7.03      PN  1728613084
# 1        1.03      GL  1728613084
# 2        2.88      KZ  1728613085
# 3        3.09      US  1728613085
# 4        3.60      US  1728613085

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           adamstown -25.0660 -130.1015     21.29        87         100
# 1           ilulissat  69.2167  -51.1000     -1.99        43          46
# 2               lepsy  46.2350   78.9456     17.30        35         100
# 3              bethel  41.3712  -73.4140      9.05        69           0
# 4        black forest  39.0131 -104.7008     16.55        29           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.03      PN  1728613084
# 1              1.03      GL  1728613084
# 2              2.88      KZ  1728613085
# 3              3.09      US  1728613085
# 4              3.60      US  1728613085

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(X, y, x_label, y_label, title):
    """
    Create a linear regression plot.
    
    Parameters:
    X : array-like
        Input data for independent variable.
    y : array-like
        Target data for dependent variable.
    x_label : str
        Label for the x-axis.
    y_label : str
        Label for the y-axis.
    title : str
        Title of the plot.
    """
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(X, y)

    # Calculate predicted y values
    y_pred = intercept + slope * X

# Plotting
    plt.figure(figsize=(10, 6))
    plt.scatter(X, y, color='blue', label='Data points')
    plt.plot(X, y_pred, color='red', label='Regression line')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.grid()

plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           ilulissat  69.2167  -51.1000     -1.99        43          46
# 2               lepsy  46.2350   78.9456     17.30        35         100
# 3              bethel  41.3712  -73.4140      9.05        69           0
# 4        black forest  39.0131 -104.7008     16.55        29           0
# 5            sisimiut  66.9395  -53.6735      1.87        64          13
#
#          Wind Speed Country        Date
# City_ID
# 1              1.03      GL  1728613084
# 2              2.88      KZ  1728613085
# 3              3.09      US  1728613085
# 4              3.60      US  1728613085
# 5              3.01      GL  1728613085

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            adamstown -25.0660 -130.1015     21.29        87         100
# 6         punta arenas -53.1500  -70.9167      5.06        75          75
# 7            mont-dore -22.2833  166.5833     24.07        62           0
# 9             waitangi -43.9535 -176.5597     11.57        69          80
# 10       port mathurin -19.6833   63.4167     22.31        79         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.03      PN  1728613084
# 6              9.77      CL  1728613086
# 7              5.80      NC  1728613086
# 9              0.89      NZ  1728613086
# 10            10.56      MU  1728613086

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
# Out:
# The r-value is:-0.8732641375449802

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,295),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.7214431131806046

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.02921259725147245

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.06285035277061135

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.10026962442642356

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.1266850269792813

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,8),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.25977282379144817

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.2009205942079104

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
